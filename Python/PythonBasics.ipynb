# %% [markdown]
# # Python For Data Science
# ### Starting The Journey

# %%
print("Hello""World")
print('Hello','World')
# Out:
# HelloWorld
# Hello World

# %% [markdown]
# To run iPython Shell, type `ipython` command in Anaconda Powershell Prompt.
# iPython Shell works almost like a calculator.

# %%
print("Before single line comment")
#This is single line comment
print("Single comment has not been printed")
print()

print("Before multiple line comments")
"""
This is multiple line comment
I am Sajjadur Rahman
I am learning python language
"""
print("Multiple comments have not been printed")
# Out:
# Before single line comment
# Single comment has not been printed
#
# Before multiple line comments
# Multiple comments have not been printed

# %% [markdown]
# ### Variables

# %%
a, b, c, d, e, x = 3, 5.2, 2-4j, "Hello", True, 10
print(type(a+b))
del x                       #x will be deleted
# Out:
# <class 'float'>

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        3
# b          float      5.2
# c          complex    (2-4j)
# d          str        Hello
# e          bool       True

# %% [markdown]
# ### Operators

# %%
print(5/2)                  #normal division
print(5//2)                 #floor division
print("Hello" + "Sajjad")   #concatenation
2**4                        #2 to the power 4
# Out:
# 2.5
# 2
# HelloSajjad
# 16

# %% [markdown]
# Variable naming rules are same as C/C++/Java.
# Underscore(_) stores the last value that we did not assign to a particular variable explicity.

# %%
print(_)
# Out:
# 16

# %% [markdown]
# In Python, logical operators are : `and`, `or`, `not`.
# ### Some Useful Functions

# %%
print(round(5.6231))
print(round(4.55852,3))
# Out:
# 6
# 4.559

# %%
print(divmod(27,5))         #prints (quotient, remainder)
# Out:
# (5, 2)

# %%
print(isinstance(1,int))
print(isinstance(1.0,int))
print(isinstance(1.0,(int,float)))
# Out:
# True
# False
# True

# %%
print(pow(2,5))             #2 to the power 5
print(pow(2,5,10))          #(2 to the power 5) mod 10
# Out:
# 32
# 2

# %% [markdown]
# input() function accepts inputs from the user as a `str` type data.

# %%
x = input("Enter x = ")
print(type(x))
x = int(x)
print(type(x))
# Out:
# Enter x = 10
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Control Statements

# %%
a = float(input("Enter a = "))
b = float(input("Enter b = "))

if a > b:
    print("a is greater than b")
elif a < b:
    print("a is less than b")
else:
    print("a is equal to b")
    
print("a > b") if a > b else print("a < b") if a < b else print("a = b")
print(int(b))
# Out:
# Enter a = 5
# Enter b = 4.99
# a is greater than b
# a > b
# 4

# %% [markdown]
# ### Loops

# %%
n = int(input("Enter n = "))
i = 1
while i < n:
    if i%2 == 0:
        print(i)
    else:
        pass
    i += 1
# Out:
# Enter n = 10
# 2
# 4
# 6
# 8

# %%
L = []
for i in range(0, 10, 2):   #range(start location, end location, jump), 10 will not be included
    L.append(i)
print(L)
print("Length =", len(L))
# Out:
# [0, 2, 4, 6, 8]
# Length = 5

# %%
S = {"apple", 4.9, "cherry"}
for x in S:
    print(x)
    #break
else:     #if we forcefully terminate the loop by 'break' statement, 'else' bock will not be executed
    print("Loop terminates completing all of its iterations")
print("Outside the loop")
# Out:
# apple
# 4.9
# cherry
# Loop executions done

# %% [markdown]
# ### Functions
# Whenever placing ? and ?? after any function gives us the same output in the window, that means the function is not written in plain python, it is written in some other language and used in python.

# %%
def printName(name):
    """
    This function prints someone's name.
    """
    if isinstance(name, str):
        print(name)
    else:
        print(name, "is not a string")

# %% [markdown]
# By placing ? and ?? after any function name will open up a window showing the Document string(Docstring) and the implementation of that function respectively.

# %%
printName?

# %%
printName??

# %% [markdown]
# help(function name) will print the Docstring of a function.

# %%
help(printName)
# Out:
# Help on function printName in module __main__:
#
# printName()
#     This function prints my name.

# %% [markdown]
# In python, a function always returns a value.

# %%
print(printName("Samiur"))
print(type(printName("Taha")))
# Out:
# Samiur
# None
# Taha
# <class 'NoneType'>

# %%
def printValue(v2, v3, v1):
    print("v1 =", v1)
    print("v2 =", v2)
    print("v3 =", v3)

printValue(v2 = 'H', v3 = 5, v1 = 3.4)
# Out:
# v1 = 3.4
# v2 = H
# v3 = 5

# %% [markdown]
# Also, a function can return multiple values.

# %%
def returnValue():
    return a, b, a+b

a, b = 3, 5.7
a, b, sum = returnValue()
print("a =", a)
print("b =", b)
print("sum =", sum)
# Out:
# a = 3
# b = 5.7
# sum = 8.7

# %%
def myAdd(*args):
    sum = 0
    for i in range(len(args)):
        sum += args[i]
    return sum

print("Sum =", myAdd(3, 4, 6))
# Out:
# Sum = 13

# %%
def printVariablesAndValues(**args):
    for x in args:
        print(x, "=", args[x])
        
printVariablesAndValues(a = 3, b = 'B', c = 2-3j, d = 6.3)
# Out:
# a = 3
# b = B
# c = (2-3j)
# d = 6.3

# %% [markdown]
# We can assign default values to function arguments.

# %%
def fun(x = 4):
    print("x =", x)
    
fun()
fun(10)
fun()
# Out:
# x = 4
# x = 10
# x = 4

# %%
def printList(L = [1, 2, 3]):
    print(L)
 
L = [6, 7, 8]
printList()
printList(L)
printList()
# Out:
# [1, 2, 3]
# [6, 7, 8]
# [1, 2, 3]

# %% [markdown]
# ### Modules
# Modules are python files that contains some code that we want to use in several different projects. To use any segment of that code we have to import the whole module. To use the modules we need to specify the path where the module resides.

# %%
import sys     #this is a system module
sys.path.append("C:/Users/Lanja Lan/Documents/Codes/Python")
import MyModule as m
print(m.addAllNumerics(2, 3, 4, 6))
print(m.courseName)
# Out:
# 15
# Python Course

# %% [markdown]
# We can alsp import one or multiple functions from a module.

# %%
from MyModule import isNumeric
print(isNumeric(2, 3, 4, 'a'))
# Out:
# False

# %% [markdown]
# If the modules are arranged in a directory structure, that directory structure is sometimes called package.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
import math

titanic_data = pd.read_csv("Titanic.csv")
titanic_data.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3768\1299785819.py in <module>
#       7 import math
#       8
# ----> 9 titanic_data = pd.read_csv("Titanic.csv")
#      10 titanic_data.head(10)
#
# C:\Program Files\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Program Files\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# C:\Program Files\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# C:\Program Files\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# C:\Program Files\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# C:\Program Files\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Titanic.csv'
